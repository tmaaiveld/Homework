# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("chapter2_result_500.csv")



# df = df.fillna(method='ffill')

df

# df.to_csv('imputed.csv',index=False)
# Out:
#                    Unnamed: 0  acc_phone_x  acc_phone_y  acc_phone_z  \
# 0     1970-01-01 00:00:00.000    -1.417740     2.066928     9.340163
# 1     1970-01-01 00:00:00.500     2.766312     1.562893     5.135254
# 2     1970-01-01 00:00:01.000     7.423109   -12.551694     4.188782
# 3     1970-01-01 00:00:01.500     1.398233   -10.935696     2.249600
# 4     1970-01-01 00:00:02.000     5.984516    -7.490723    -2.017858
# 5     1970-01-01 00:00:02.500     5.732437    -7.303652    -1.536932
# 6     1970-01-01 00:00:03.000     2.714840    -8.711320     0.953971
# 7     1970-01-01 00:00:03.500     2.122021    -9.294520     0.642856
# 8     1970-01-01 00:00:04.000     1.885066   -10.301640     0.312448
# 9     1970-01-01 00:00:04.500     0.468922    -9.725920     0.532993
# 10    1970-01-01 00:00:05.000    -0.001823    -9.537800     2.144280
# 11    1970-01-01 00:00:05.500     0.679556    -9.582640     1.233403
# 12    1970-01-01 00:00:06.000    -0.386629   -10.399357     2.029829
# ...
